# %% [markdown]
# # 03 · HAR-RV — Heterogeneous Autoregression
# GARCH Volatility Series | Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
from garch_models import har_rv_variance
import numpy as np, pandas as pd
print("OK")

# %%
df=pd.read_csv("../data/garch_estimates.csv")
print("HAR-RV vs GARCH volatility correlation:")
print(df[["garch_vol","har_vol"]].corr().to_string())
print("\nHAR-RV mean vol:", df["har_vol"].mean().round(4), "%")

# %%
import matplotlib.pyplot as plt
img=plt.imread("../results/06_realized_vs_garch.png")
fig,ax=plt.subplots(figsize=(15,10)); ax.imshow(img); ax.axis("off"); plt.show()
