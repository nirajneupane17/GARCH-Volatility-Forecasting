# %% [markdown]
# # 02 · EGARCH & GJR-GARCH — Asymmetric Volatility
# GARCH Volatility Series | Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
from garch_models import egarch_variance, gjr_garch_variance, news_impact_curve
import numpy as np, pandas as pd
print("OK")

# %%
df=pd.read_csv("../data/garch_estimates.csv"); r=df["return_pct"].values/100
print("GJR effective alpha (negative shock):", 0.06+0.08)
print("GJR effective alpha (positive shock):", 0.06)
print("Leverage ratio:", round((0.06+0.08)/0.06,2), "x")

# %%
import matplotlib.pyplot as plt
img=plt.imread("../results/03_news_impact_curve.png")
fig,ax=plt.subplots(figsize=(18,6)); ax.imshow(img); ax.axis("off"); plt.show()
