# %% [markdown]
# # 05 · Walk-Forward Forecast Tournament
# GARCH Volatility Series — Project 5 Complete | Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
from forecast_engine import forecast_accuracy
import pandas as pd
print("OK")

# %%
oos=pd.read_csv("../data/forecasts_oos.csv"); acc=pd.read_csv("../data/forecast_accuracy.csv",index_col=0)
print("Forecast Accuracy (1,509 out-of-sample days):")
print(acc.to_string())
print(f"\nBest RMSE: {acc["RMSE"].idxmin()} ({acc["RMSE"].min():.4f})")

# %%
import matplotlib.pyplot as plt
img=plt.imread("../results/05_forecast_tournament.png")
fig,ax=plt.subplots(figsize=(15,10)); ax.imshow(img); ax.axis("off"); plt.show()
print("\nProject 5 complete.")
