# %% [markdown]
# # 04 · Markov-Switching Regime Detection
# GARCH Volatility Series | Niraj Neupane | github.com/nirajneupane17

# %%
import sys; sys.path.insert(0,"../src")
from regime_detector import rolling_regime, regime_statistics
import pandas as pd, numpy as np
print("OK")

# %%
df=pd.read_csv("../data/garch_estimates.csv"); r=df["return_pct"].values/100
states=df["ms_state"].values
stats=regime_statistics(r,states)
print("Regime Statistics:")
for k,v in stats.items(): print(f"  {k}: {v}")

# %%
import matplotlib.pyplot as plt
img=plt.imread("../results/04_regime_detection.png")
fig,ax=plt.subplots(figsize=(15,10)); ax.imshow(img); ax.axis("off"); plt.show()
